# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Libraries imported.

# %%
pip install BeautifulSoup4
# Out:
# Requirement already satisfied: BeautifulSoup4 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (4.8.1)
# Requirement already satisfied: soupsieve>=1.2 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from BeautifulSoup4) (1.9.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install lxml
# Out:
# Requirement already satisfied: lxml in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (4.4.2)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# #### Use beautifulSoup to scrape data from wiki

# %%
from bs4 import BeautifulSoup
res = requests.get("https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M")
soup = BeautifulSoup(res.content,'lxml')
table = soup.find_all('table')[0] 
df = pd.read_html(str(table))[0]

# %% [markdown]
# #### Clean the table

# %%
df3 = df.copy()
df2 = []
for i in range(0,len(df)):
   if df3.iloc[i,1] != "Not assigned" and df3.iloc[i,2] != "Not assigned" and df3.iloc[i,1] != df3.iloc[i-1,1]:
     df2.append(df3.iloc[i,:]) 
   elif df3.iloc[i,1] != "Not assigned" and df3.iloc[i,2] != "Not assigned" and df3.iloc[i,1] == df3.iloc[i-1,1] and df3.iloc[i,0] == df3.iloc[i-1,0]:    
    df2[len(df2)-1][2] = df3.iloc[i-1,2] + "," + df3.iloc[i,2]
   elif df3.iloc[i,1] != "Not assigned" and df3.iloc[i,2] == "Not assigned":
     df2.append(df3.iloc[i,:])
     df2[len(df2)-1][2] = df2[len(df2)-1][1]
df2 = pd.DataFrame(df2)

# %%
df2.shape
# Out:
# (88, 3)

# %%
df2.head()
# Out:
#   Postcode           Borough                    Neighbourhood
# 2      M3A        North York                        Parkwoods
# 4      M5A  Downtown Toronto                     Harbourfront
# 5      M6A        North York  Lawrence Heights,Lawrence Manor
# 7      M7A      Queen's Park                     Queen's Park
# 9      M9A  Downtown Toronto                     Queen's Park

# %%
Location = pd.read_csv("http://cocl.us/Geospatial_data")

# %%
Location.columns = ['Postcode', 'Latitude','Longitude']

# %%
Location.head()
# Out:
#   Postcode   Latitude  Longitude
# 0      M1B  43.806686 -79.194353
# 1      M1C  43.784535 -79.160497
# 2      M1E  43.763573 -79.188711
# 3      M1G  43.770992 -79.216917
# 4      M1H  43.773136 -79.239476

# %%
result = pd.merge(df2, Location, on='Postcode')

# %%
result
# Out:
#    Postcode           Borough  \
# 0       M3A        North York
# 1       M5A  Downtown Toronto
# 2       M6A        North York
# 3       M7A      Queen's Park
# 4       M9A  Downtown Toronto
# 5       M1B       Scarborough
# 6       M3B        North York
# 7       M4B         East York
# 8       M5B  Downtown Toronto
# 9       M6B        North York
# 10      M9B         Etobicoke
# 11      M1C       Scarborough
# 12      M3C        North York
# 13      M4C         East York
# 14      M5C  Downtown Toronto
# 15      M6C              York
# 16      M9C         Etobicoke
# 17      M1E       Scarborough
# 18      M4E      East Toronto
# 19      M5E  Downtown Toronto
# 20      M6E              York
# 21      M1G       Scarborough
# 22      M4G         East York
# 23      M5G  Downtown Toronto
# 24      M1H       Scarborough
# 25      M2H        North York
# 26      M4H         East York
# 27      M5H  Downtown Toronto
# 28      M6H      West Toronto
# 29      M1J       Scarborough
# 30      M2J        North York
# 31      M4J         East York
# 32      M5J  Downtown Toronto
# 33      M6J      West Toronto
# 34      M1K       Scarborough
# 35      M2K        North York
# 36      M4K      East Toronto
# 37      M5K  Downtown Toronto
# 38      M6K      West Toronto
# 39      M1L       Scarborough
# 40      M2L        North York
# 41      M4L      East Toronto
# 42      M5L  Downtown Toronto
# 43      M6L        North York
# 44      M9L        North York
# 45      M1M       Scarborough
# 46      M2M        North York
# 47      M4M      East Toronto
# 48      M5M        North York
# 49      M6M              York
# 50      M9M        North York
# 51      M1N       Scarborough
# 52      M2N        North York
# 53      M4N   Central Toronto
# 54      M6N              York
# 55      M9N              York
# 56      M1P       Scarborough
# 57      M2P        North York
# 58      M4P   Central Toronto
# 59      M6P      West Toronto
# 60      M9P         Etobicoke
# 61      M1R       Scarborough
# 62      M2R        North York
# 63      M4R   Central Toronto
# 64      M6R      West Toronto
# 65      M7R       Mississauga
# 66      M9R         Etobicoke
# 67      M1S       Scarborough
# 68      M4S   Central Toronto
# 69      M5S  Downtown Toronto
# 70      M6S      West Toronto
# 71      M1T       Scarborough
# 72      M4T   Central Toronto
# 73      M5T  Downtown Toronto
# 74      M1V       Scarborough
# 75      M4V   Central Toronto
# 76      M5V  Downtown Toronto
# 77      M8V         Etobicoke
# 78      M1W       Scarborough
# 79      M4W  Downtown Toronto
# 80      M8W         Etobicoke
# 81      M1X       Scarborough
# 82      M4X  Downtown Toronto
# 83      M8X         Etobicoke
# 84      M4Y  Downtown Toronto
# 85      M7Y      East Toronto
# 86      M8Y         Etobicoke
# 87      M8Z         Etobicoke
#
#                                         Neighbourhood   Latitude  Longitude
# 0                                           Parkwoods  43.753259 -79.329656
# 1                                        Harbourfront  43.654260 -79.360636
# 2                     Lawrence Heights,Lawrence Manor  43.718518 -79.464763
# 3                                        Queen's Park  43.662301 -79.389494
# 4                                        Queen's Park  43.667856 -79.532242
# 5                                       Rouge,Malvern  43.806686 -79.194353
# 6                                     Don Mills North  43.745906 -79.352188
# 7                      Woodbine Gardens,Parkview Hill  43.706397 -79.309937
# 8                             Ryerson,Garden District  43.657162 -79.378937
# 9                                           Glencairn  43.709577 -79.445073
# 10                   Princess Gardens,West Deane Park  43.650943 -79.554724
# 11                              Rouge Hill,Port Union  43.784535 -79.160497
# 12                    Flemingdon Park,Don Mills South  43.725900 -79.340923
# 13                                   Woodbine Heights  43.695344 -79.318389
# 14                                     St. James Town  43.651494 -79.375418
# 15                                 Humewood-Cedarvale  43.693781 -79.428191
# 16                    Markland Wood,Old Burnhamthorpe  43.643515 -79.577201
# 17                              Morningside,West Hill  43.763573 -79.188711
# 18                                        The Beaches  43.676357 -79.293031
# 19                                        Berczy Park  43.644771 -79.373306
# 20                                Caledonia-Fairbanks  43.689026 -79.453512
# 21                                             Woburn  43.770992 -79.216917
# 22                                            Leaside  43.709060 -79.363452
# 23                                 Central Bay Street  43.657952 -79.387383
# 24                                          Cedarbrae  43.773136 -79.239476
# 25                     Downsview North,Wilson Heights  43.803762 -79.363452
# 26                                   Thorncliffe Park  43.705369 -79.349372
# 27                                      King,Richmond  43.650571 -79.384568
# 28                        Dovercourt Village,Dufferin  43.669005 -79.442259
# 29                                Scarborough Village  43.744734 -79.239476
# 30                     Northwood Park,York University  43.778517 -79.346556
# 31                                       East Toronto  43.685347 -79.338106
# 32                      Toronto Islands,Union Station  43.640816 -79.381752
# 33                            Little Portugal,Trinity  43.647927 -79.419750
# 34                               Ionview,Kennedy Park  43.727929 -79.262029
# 35                         CFB Toronto,Downsview East  43.786947 -79.385975
# 36                        The Danforth West,Riverdale  43.679557 -79.352188
# 37            Design Exchange,Toronto Dominion Centre  43.647177 -79.381576
# 38                  Exhibition Place,Parkdale Village  43.636847 -79.428191
# 39                               Golden Mile,Oakridge  43.711112 -79.284577
# 40                            Silver Hills,York Mills  43.757490 -79.374714
# 41                      The Beaches West,India Bazaar  43.668999 -79.315572
# 42                      Commerce Court,Victoria Hotel  43.648198 -79.379817
# 43                             North Park,Upwood Park  43.713756 -79.490074
# 44                                      Humber Summit  43.756303 -79.565963
# 45                 Cliffside,Scarborough Village West  43.716316 -79.239476
# 46                             Newtonbrook,Willowdale  43.789053 -79.408493
# 47                                    Studio District  43.659526 -79.340923
# 48                   Bedford Park,Lawrence Manor East  43.733283 -79.419750
# 49                           Mount Dennis,Silverthorn  43.691116 -79.476013
# 50                                    Emery,Humberlea  43.724766 -79.532242
# 51                         Birch Cliff,Cliffside West  43.692657 -79.264848
# 52                                   Willowdale South  43.770120 -79.408493
# 53                                      Lawrence Park  43.728020 -79.388790
# 54                       The Junction North,Runnymede  43.673185 -79.487262
# 55                                             Weston  43.706876 -79.518188
# 56            Scarborough Town Centre,Wexford Heights  43.757410 -79.273304
# 57                                    York Mills West  43.752758 -79.400049
# 58                 Forest Hill North,Forest Hill West  43.712751 -79.390197
# 59                       High Park,The Junction South  43.661608 -79.464763
# 60                                          Westmount  43.696319 -79.532242
# 61                                   Maryvale,Wexford  43.750072 -79.295849
# 62                                    Willowdale West  43.782736 -79.442259
# 63                            North Midtown,Yorkville  43.715383 -79.405678
# 64                              Parkdale,Roncesvalles  43.648960 -79.456325
# 65              Canada Post Gateway Processing Centre  43.636966 -79.615819
# 66                      Richview Gardens,St. Phillips  43.688905 -79.554724
# 67                                          Agincourt  43.794200 -79.262029
# 68                                         Davisville  43.704324 -79.388790
# 69                      Harbord,University of Toronto  43.662696 -79.400049
# 70                                  Runnymede,Swansea  43.651571 -79.484450
# 71                             Sullivan,Tam O'Shanter  43.781638 -79.304302
# 72                         Moore Park,Summerhill East  43.689574 -79.383160
# 73                      Grange Park,Kensington Market  43.653206 -79.400049
# 74                              Milliken,Steeles East  43.815252 -79.284577
# 75                         South Hill,Summerhill West  43.686412 -79.400049
# 76                        Railway Lands,South Niagara  43.628947 -79.394420
# 77                          South Steeles,Thistletown  43.605647 -79.501321
# 78                                    L'Amoreaux West  43.799525 -79.318389
# 79                                           Rosedale  43.679563 -79.377529
# 80                              Alderwood,Long Branch  43.602414 -79.543484
# 81                                        Upper Rouge  43.836125 -79.205636
# 82              First Canadian Place,Underground city  43.667967 -79.367675
# 83                     Montgomery Road,Old Mill North  43.653654 -79.506944
# 84                               Church and Wellesley  43.665860 -79.383160
# 85  Business Reply Mail Processing Centre 969 Eastern  43.662744 -79.321558
# 86                     Royal York South East,Sunnylea  43.636258 -79.498509
# 87               Royal York South West,South of Bloor  43.628841 -79.520999
